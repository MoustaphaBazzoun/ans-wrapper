# %%
from ans_wrapper import DemonstracoesContabeis
import pandas as pd

# %%
dem = DemonstracoesContabeis()

# %% [markdown]
# ##### Sandbox

# %%
df = pd.read_csv("../ans_downloads/1T2025.csv", delimiter=";")

# %%
codigos_ans = set(df['REG_ANS'])

# %%
company_date = df.loc[df["REG_ANS"]== 316458]

# %% [markdown]
# ##### Quarter Industry Data

# %%
# Quarter Info 1T2025
df = dem.get_info("1T2025")
df.head()
# Out:
# ZIP file saved at: ans_downloads/1T2025.zip
# CSV extracted: ans_downloads/1T2025.csv
#          DATA  REG_ANS  CD_CONTA_CONTABIL                 DESCRICAO  \
# 0  2025-01-01   316458              46411  PUBLICIDADE E PROPAGANDA
# 1  2025-01-01   316458             464119  Publicidade e Propaganda
# 2  2025-01-01   316458           46411901  Publicidade e Propaganda
# 3  2025-01-01   316458          464119011  Publicidade e Propaganda
# 4  2025-01-01   316458                465     DESPESAS COM TRIBUTOS
#
#   VL_SALDO_INICIAL VL_SALDO_FINAL
# 0                0           1070
# 1                0           1070
# 2                0           1070
# 3                0           1070
# 4                0       99024,72

# %%
df["REG_ANS"].values
# Out:
# array([316458, 316458, 316458, ..., 379280, 379280, 379280],
#       shape=(705390,))

# %%
a = [316458, 379280, 102301]  
b = [x for x in a if x not in df["REG_ANS"].values]

# %%
b
# Out:
# [102301]

# %% [markdown]
# ##### Getting Company Data

# %%
# Código ANS do GNDI
GNDI = 359017
# Info Trimestral GNDI
df = dem.get_info("1T2023", GNDI)
# Out:
# -------
# {'Date': 'Tue, 12 Aug 2025 22:20:28 GMT', 'Server': 'Apache/2.4.6 () OpenSSL/1.0.2k-fips', 'Last-Modified': 'Tue, 13 Jun 2023 13:45:15 GMT', 'ETag': '"79305a-5fe030b8250c0"', 'Accept-Ranges': 'bytes', 'Content-Length': '7942234', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'application/zip'}
# -------
# 1T2023.zip: 100%|██████████| 7.94M/7.94M [00:06<00:00, 1.17MB/s]
# ZIP file saved at: ans_downloads/1T2023.zip
# CSV extracted: ans_downloads/1T2023.csv

# %%
df.head()
# Out:
#             DATA  REG_ANS  CD_CONTA_CONTABIL  \
# 1546  2023-01-01   359017              21861
# 1547  2023-01-01   359017             218619
# 1548  2023-01-01   359017           21861901
# 1549  2023-01-01   359017          218619011
# 1550  2023-01-01   359017               2187
#
#                                               DESCRICAO VL_SALDO_INICIAL  \
# 1546                  DÉBITOS COM AQUISIÇÃO DE CARTEIRA       6652597,76
# 1547                  Débitos com Aquisição de Carteira       6652597,76
# 1548                  Débitos com Aquisição de Carteira       6652597,76
# 1549  Débitos com Aquisição de Carteira de Beneficiá...       6652597,76
# 1550          PASSIVO DE ARRENDAMENTOS - VALOR PRESENTE      38635342,99
#
#      VL_SALDO_FINAL
# 1546     3910498,02
# 1547     3910498,02
# 1548     3910498,02
# 1549     3910498,02
# 1550    38735806,11

# %%
# Get filtered dataset for specific companies (using real company codes)
df_filtered = dem.get_info(quarters="1T2023", company="316458")
print("Filtered dataset shape:", df_filtered.shape)
# Out:
# -------
# {'Date': 'Tue, 12 Aug 2025 13:54:40 GMT', 'Server': 'Apache/2.4.6 () OpenSSL/1.0.2k-fips', 'Last-Modified': 'Tue, 13 Jun 2023 13:45:15 GMT', 'ETag': '"79305a-5fe030b8250c0"', 'Accept-Ranges': 'bytes', 'Content-Length': '7942234', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'application/zip'}
# -------
# ZIP file saved at: ans_downloads/1T2023.zip
# CSV extracted: ans_downloads/1T2023.csv
# Filtered dataset shape: (472, 6)

# %% [markdown]
# ##### Multiple Company Data

# %%
df_multiple_company = dem.get_info(quarters="1T2023", company=["316458", "356476"])
# Out:
# -------
# {'Date': 'Tue, 12 Aug 2025 22:21:15 GMT', 'Server': 'Apache/2.4.6 () OpenSSL/1.0.2k-fips', 'Last-Modified': 'Tue, 13 Jun 2023 13:45:15 GMT', 'ETag': '"79305a-5fe030b8250c0"', 'Accept-Ranges': 'bytes', 'Content-Length': '7942234', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'application/zip'}
# -------
# 1T2023.zip: 100%|██████████| 7.94M/7.94M [00:06<00:00, 1.16MB/s]
# ZIP file saved at: ans_downloads/1T2023.zip
# CSV extracted: ans_downloads/1T2023.csv

# %%
df_multiple_company = dem.get_info(quarters="1T2023", company=["316458", "356476", "301923802938210931"])
# Out:
# ZIP file saved at: ans_downloads/1T2023.zip
# CSV extracted: ans_downloads/1T2023.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_multiple_company = dem.get_info(quarters="1T2023", company=["316458", "356476", "301923802938210931"])
#
# File ~/Desktop/ans-wrapper/src/ans_wrapper/demonstracoes_contabeis.py:102, in DemonstracoesContabeis.get_info(self, quarters, company)
#      98 missing_codes = [code for code in company_list
#      99                  if code not in combined_df['REG_ANS'].unique()]
#     101 if missing_codes:
# --> 102     raise ValueError(f"Company code(s) not found in dataset: {missing_codes}")
#     104 filtered_df = combined_df[combined_df['REG_ANS'].isin(company_list)]
#     106 if filtered_df.empty:
#
# ValueError: Company code(s) not found in dataset: [301923802938210931]

# %%
df_multiple_company.head()
# Out:
#            DATA  REG_ANS  CD_CONTA_CONTABIL  \
# 642  2023-01-01   356476              46151
# 643  2023-01-01   356476             461519
# 644  2023-01-01   356476           46151901
# 645  2023-01-01   356476          461519011
# 646  2023-01-01   356476               4616
#
#                                          DESCRICAO VL_SALDO_INICIAL  \
# 642                DESPESAS COM ASSISTÊNCIA SOCIAL                0
# 643                Despesas com Assistência Social                0
# 644                Despesas com Assistência Social                0
# 645  Despesas com Assistência Médica/ Odontológica                0
# 646                         DESPESAS COM INSTRUÇÃO                0
#
#     VL_SALDO_FINAL
# 642       31661,21
# 643       31661,21
# 644       31661,21
# 645       31661,21
# 646       70171,18

# %%
set(df_multiple_company["REG_ANS"])
# Out:
# {316458, 356476}

# %% [markdown]
# ##### Multiple Quarters

# %%
df_multiple_company = dem.get_info(quarters=["1T2023", "1T2024"], company=["316458", "356476"])
# Out:
# 1T2023.zip: 100%|██████████| 7.94M/7.94M [00:07<00:00, 1.13MB/s]
# ZIP file saved at: ans_downloads/1T2023.zip
# CSV extracted: ans_downloads/1T2023.csv
# 1T2024.zip: 100%|██████████| 8.23M/8.23M [00:07<00:00, 1.17MB/s]
# ZIP file saved at: ans_downloads/1T2024.zip
# CSV extracted: ans_downloads/1T2024.csv
