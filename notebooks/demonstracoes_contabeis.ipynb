# %%
from ans_wrapper import DemonstracoesContabeis
import pandas as pd

# %%
dem = DemonstracoesContabeis()

# %% [markdown]
# ##### Sandbox

# %%
df = pd.read_csv("../ans_downloads/1T2025.csv", delimiter=";")

# %%
codigos_ans = set(df['REG_ANS'])

# %%
len(set(codigos_ans))
# Out:
# 779

# %%
company_date = df.loc[df["REG_ANS"]== 316458]

# %%
company_date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 company_date
#
# NameError: name 'company_date' is not defined

# %% [markdown]
# ##### Quarter Industry Data

# %%
# Quarter Info 1T2025
df = dem.get_info("1T2025")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Quarter Info 1T2025
# ----> 2 df = dem.get_info("1T2025")
#
# AttributeError: 'DemonstracoesContabeis' object has no attribute 'get_info'

# %% [markdown]
# ##### Getting Company Data

# %%
# Código ANS do GNDI
GNDI = 359017

# %%
# Info Trimestral GNDI
df = dem.get_info(GNDI, "1T2025")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Info Trimestral GNDI
# ----> 2 df = dem.get_info(GNDI, "1T2025")
#
# AttributeError: 'DemonstracoesContabeis' object has no attribute 'get_info'

# %%
# Get filtered dataset for specific companies (using real company codes)
df_filtered = dem.get_info(quarters="1T2025", company=["000477", "000515"])
print("Filtered dataset shape:", df_filtered.shape)
# Out:
# ZIP file saved at: ans_downloads/1T2025.zip
# CSV extracted: ans_downloads/1T2025.csv
# Warning: No data found for companies ['000477', '000515']
# Filtered dataset shape: (0, 6)
