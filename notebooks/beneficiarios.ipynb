# %%
from ans_wrapper import Beneficiarios

# %%
beneficiarios = Beneficiarios()

# %% [markdown]
# ##### Basic Props

# %%
beneficiarios.available_months
# Out:
# ['201904',
#  '201905',
#  '201906',
#  '201907',
#  '201908',
#  '201909',
#  '201910',
#  '201911',
#  '201912',
#  '202001',
#  '202002',
#  '202003',
#  '202004',
#  '202005',
#  '202006',
#  '202007',
#  '202008',
#  '202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202102',
#  '202103',
#  '202104',
#  '202105',
#  '202106',
#  '202107',
#  '202108',
#  '202109',
#  '202110',
#  '202111',
#  '202112',
#  '202201',
#  '202202',
#  '202203',
#  '202204',
#  '202205',
#  '202206',
#  '202207',
#  '202208',
#  '202209',
#  '202210',
#  '202211',
#  '202212',
#  '202301',
#  '202302',
#  '202303',
#  '202304',
#  '202305',
#  '202306',
#  '202307',
#  '202308',
#  '202309',
#  '202310',
#  '202311',
#  '202312',
#  '202401',
#  '202402',
#  '202403',
#  '202404',
#  '202405',
#  '202406',
#  '202407',
#  '202408',
#  '202409',
#  '202410',
#  '202411',
#  '202412',
#  '202501',
#  '202502',
#  '202503',
#  '202504',
#  '202505',
#  '202506']

# %%
beneficiarios.info
# Out:
# Beneficiários data available:
# data available from Apr 2019 to Jun 2025
# 75 months available
# Source: https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/

# %% [markdown]
# ##### Core Function: Downloading raw datasets

# %%
df1 = beneficiarios.download_raw_data(
    states=["SP", "RJ"],
    dates=["202401", "202402"]
)
# Out:
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202401/pda-024-icb-SP-2024_01.zip
# pda-024-icb-SP-2024_01.zip: 100%|██████████| 132M/132M [02:12<00:00, 998kB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-SP-2024_01.zip
# CSV extracted: ans_downloads/pda-024-icb-SP-2024_01.csv
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202402/pda-024-icb-SP-2024_02.zip
# pda-024-icb-SP-2024_02.zip: 100%|██████████| 132M/132M [01:25<00:00, 1.55MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-SP-2024_02.zip
# CSV extracted: ans_downloads/pda-024-icb-SP-2024_02.csv
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202401/pda-024-icb-RJ-2024_01.zip
# pda-024-icb-RJ-2024_01.zip: 100%|██████████| 29.9M/29.9M [00:18<00:00, 1.58MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-RJ-2024_01.zip
# CSV extracted: ans_downloads/pda-024-icb-RJ-2024_01.csv
# ...

# %%
beneficiarios.download_raw_data(
    states=None,
    dates=None
)
