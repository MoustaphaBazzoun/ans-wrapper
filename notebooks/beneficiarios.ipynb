# %%
import pandas as pd

# %%
from ans_wrapper import Beneficiarios

beneficiarios = Beneficiarios()

# %% [markdown]
# ##### Basic Props

# %%
beneficiarios.available_months
# Out:
# ['201904',
#  '201905',
#  '201906',
#  '201907',
#  '201908',
#  '201909',
#  '201910',
#  '201911',
#  '201912',
#  '202001',
#  '202002',
#  '202003',
#  '202004',
#  '202005',
#  '202006',
#  '202007',
#  '202008',
#  '202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202102',
#  '202103',
#  '202104',
#  '202105',
#  '202106',
#  '202107',
#  '202108',
#  '202109',
#  '202110',
#  '202111',
#  '202112',
#  '202201',
#  '202202',
#  '202203',
#  '202204',
#  '202205',
#  '202206',
#  '202207',
#  '202208',
#  '202209',
#  '202210',
#  '202211',
#  '202212',
#  '202301',
#  '202302',
#  '202303',
#  '202304',
#  '202305',
#  '202306',
#  '202307',
#  '202308',
#  '202309',
#  '202310',
#  '202311',
#  '202312',
#  '202401',
#  '202402',
#  '202403',
#  '202404',
#  '202405',
#  '202406',
#  '202407',
#  '202408',
#  '202409',
#  '202410',
#  '202411',
#  '202412',
#  '202501',
#  '202502',
#  '202503',
#  '202504',
#  '202505',
#  '202506',
#  '202507',
#  '202508',
#  '202509']

# %%
print(beneficiarios.info)
# Out:
# Beneficiários data available:
# 📅 data available from Apr 2019 to Sep 2025
# 📦 78 months available
# 🔗 Source: https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/

# %% [markdown]
# #### Core Functions

# %% [markdown]
# 1. Downloading Raw Datasets with download_raw_data():

# %%
# Downloading data from jan/2024 up to april/2024 for São Paulo and Rio de Janeiro:
datasets = beneficiarios.download_raw_data(
    states=["SP", "RJ"],
    dates=["202401", "202402"]
)

# All the downloaded datasets go to a new folder called ans_downloads, and the function
# Returns the paths to those datasets so you can easily load them with pandas
print(datasets)

example_df = pd.read_csv(datasets[0], delimiter=";")
example_df.head(5)
# Out:
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202401/pda-024-icb-SP-2024_01.zip
# pda-024-icb-SP-2024_01.zip: 100%|██████████| 132M/132M [00:39<00:00, 3.36MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-SP-2024_01.zip
# CSV extracted: ans_downloads/pda-024-icb-SP-2024_01.csv
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202402/pda-024-icb-SP-2024_02.zip
# pda-024-icb-SP-2024_02.zip: 100%|██████████| 132M/132M [00:36<00:00, 3.58MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-SP-2024_02.zip
# CSV extracted: ans_downloads/pda-024-icb-SP-2024_02.csv
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202401/pda-024-icb-RJ-2024_01.zip
# pda-024-icb-RJ-2024_01.zip: 100%|██████████| 30.0M/30.0M [00:21<00:00, 1.42MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-RJ-2024_01.zip
# CSV extracted: ans_downloads/pda-024-icb-RJ-2024_01.csv
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202402/pda-024-icb-RJ-2024_02.zip
# pda-024-icb-RJ-2024_02.zip: 100%|██████████| 29.8M/29.8M [00:13<00:00, 2.14MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-RJ-2024_02.zip
# CSV extracted: ans_downloads/pda-024-icb-RJ-2024_02.csv
# ['ans_downloads/pda-024-icb-SP-2024_01.csv',
#  'ans_downloads/pda-024-icb-SP-2024_02.csv',
#  'ans_downloads/pda-024-icb-RJ-2024_01.csv',
#  'ans_downloads/pda-024-icb-RJ-2024_02.csv']

# %% [markdown]
# 2. Fetching data as a dataframe with build_dataset()

# %%
# Want to skip the hassle of opening, cleaning, and merging multiple CSV files? 
# Just fetch the data directly as a ready-to-use DataFrame.

# Let's take a look at Santa Catarina and Porto Alegre States in the end of 2024
df = beneficiarios.build_dataset(
    states=["SC", "PR"],
    target_date="202412"
)
# Out:
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202412/pda-024-icb-SC-2024_12.zip
# pda-024-icb-SC-2024_12.zip: 100%|██████████| 17.6M/17.6M [00:05<00:00, 3.35MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-SC-2024_12.zip
# CSV extracted: ans_downloads/pda-024-icb-SC-2024_12.csv
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202412/pda-024-icb-PR-2024_12.zip
# pda-024-icb-PR-2024_12.zip: 100%|██████████| 27.1M/27.1M [00:12<00:00, 2.15MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-PR-2024_12.zip
# CSV extracted: ans_downloads/pda-024-icb-PR-2024_12.csv
# ['ans_downloads/pda-024-icb-SC-2024_12.csv', 'ans_downloads/pda-024-icb-PR-2024_12.csv']

# %%
df.head()
# Out:
#   ID_CMPT_MOVEL  CD_OPERADORA  \
# 0       2024-12        334561
# 1       2024-12        342203
# 2       2024-12        342203
# 3       2024-12        355691
# 4       2024-12        312924
#
#                                      NM_RAZAO_SOCIAL         NR_CNPJ  \
# 0   UNIMED BLUMENAU - COOPERATIVA DE TRABALHO MEDICO  82624776000147
# 1  UNIODONTO DE SC COOPERATIVA ADMINISTRADORA DE ...   2338268000163
# 2  UNIODONTO DE SC COOPERATIVA ADMINISTRADORA DE ...   2338268000163
# 3  UNIMED DO ESTADO DE SANTA CATARINA FED. EST. D...  76590884000143
# 4                            CAIXA ECONÔMICA FEDERAL    360305000104
#
#        MODALIDADE_OPERADORA SG_UF  CD_MUNICIPIO         NM_MUNICIPIO TP_SEXO  \
# 0        COOPERATIVA MÉDICA    SC        420515      Doutor Pedrinho       M
# 1  COOPERATIVA ODONTOLÓGICA    SC        421720  São Miguel do Oeste       M
# 2  COOPERATIVA ODONTOLÓGICA    SC        421950              Xanxerê       F
# 3        COOPERATIVA MÉDICA    SC        421930              Videira       M
# 4                AUTOGESTÃO    SC        420290              Brusque       F
#
#   DE_FAIXA_ETARIA  ... TP_VIGENCIA_PLANO    DE_CONTRATACAO_PLANO  \
# 0    35 a 39 anos  ...                 P    Coletivo Empresarial
# 1    25 a 29 anos  ...                 P  Individual ou Familiar
# 2    40 a 44 anos  ...                 P    Coletivo Empresarial
# 3    30 a 34 anos  ...                 P    Coletivo Empresarial
# 4    45 a 49 anos  ...                 A     Coletivo por Adesão
#
#                                 DE_SEGMENTACAO_PLANO DE_ABRG_GEOGRAFICA_PLANO  \
# 0                                         Referência      Grupo de municípios
# 1                                       Odontológico      Grupo de municípios
# 2                                       Odontológico                 Nacional
# 3                                         Referência      Grupo de municípios
# 4  Ambulatorial + Hospitalar com obstetrícia + Od...                 Nacional
#
#   COBERTURA_ASSIST_PLAN TIPO_VINCULO QT_BENEFICIARIO_ATIVO  \
# 0     Médico-hospitalar   Dependente                     1
# 1          Odontológico   Dependente                     1
# 2          Odontológico      Titular                     1
# 3     Médico-hospitalar      Titular                     1
# 4     Médico-hospitalar      Titular                     5
#
#   QT_BENEFICIARIO_ADERIDO  QT_BENEFICIARIO_CANCELADO    DT_CARGA
# 0                       0                          0  2025-10-21
# 1                       0                          0  2025-10-21
# 2                       0                          0  2025-10-21
# 3                       0                          0  2025-10-21
# 4                       0                          0  2025-10-21
#
# [5 rows x 22 columns]
