# %%
import pandas as pd

# %%
df = pd.read_csv("ans_downloads/pda-024-icb-AC-2024_01.csv", delimiter=";")

# %%
df.columns
# Out:
# Index(['ID_CMPT_MOVEL', 'CD_OPERADORA', 'NM_RAZAO_SOCIAL', 'NR_CNPJ',
#        'MODALIDADE_OPERADORA', 'SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO',
#        'TP_SEXO', 'DE_FAIXA_ETARIA', 'DE_FAIXA_ETARIA_REAJ', 'CD_PLANO',
#        'TP_VIGENCIA_PLANO', 'DE_CONTRATACAO_PLANO', 'DE_SEGMENTACAO_PLANO',
#        'DE_ABRG_GEOGRAFICA_PLANO', 'COBERTURA_ASSIST_PLAN', 'TIPO_VINCULO',
#        'QT_BENEFICIARIO_ATIVO', 'QT_BENEFICIARIO_ADERIDO',
#        'QT_BENEFICIARIO_CANCELADO', 'DT_CARGA'],
#       dtype='object')

# %%
df.head()
# Out:
#   ID_CMPT_MOVEL  CD_OPERADORA  \
# 0       2024-01        323080
# 1       2024-01        419419
# 2       2024-01        323080
# 3       2024-01        319996
# 4       2024-01        346659
#
#                                      NM_RAZAO_SOCIAL         NR_CNPJ  \
# 0                           GEAP AUTOGESTÃO EM SAÚDE   3658432000182
# 1  BRASILDENTAL OPERADORA DE PLANOS ODONTOLÓGICOS...  19962272000109
# 2                           GEAP AUTOGESTÃO EM SAÚDE   3658432000182
# 3  UNIMED DO ESTADO DE SÃO PAULO - FEDERAÇÃO ESTA...  43643139000166
# 4  CAIXA DE ASSISTÊNCIA DOS FUNCIONÁRIOS DO BANCO...  33719485000127
#
#    MODALIDADE_OPERADORA SG_UF  CD_MUNICIPIO    NM_MUNICIPIO TP_SEXO  \
# 0            AUTOGESTÃO    AC        120040      Rio Branco       M
# 1  ODONTOLOGIA DE GRUPO    AC        120040      Rio Branco       M
# 2            AUTOGESTÃO    AC        120040      Rio Branco       M
# 3    COOPERATIVA MÉDICA    AC        120040      Rio Branco       M
# ...
