# %%
from src.ans_wrapper import Beneficiarios
import pandas as pd

# %%
beneficiarios = Beneficiarios()

beneficiarios.build_dataset(
    states=["AC", "RO"],
    target_date="202401"
)
# Out:
# ['202401'] ['AC', 'RO']
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202401/pda-024-icb-AC-2024_01.zip
# pda-024-icb-AC-2024_01.zip: 100%|██████████| 400k/400k [00:00<00:00, 2.53MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-AC-2024_01.zip
# CSV extracted: ans_downloads/pda-024-icb-AC-2024_01.csv
# https://dadosabertos.ans.gov.br/FTP/PDA/informacoes_consolidadas_de_beneficiarios-024/202401/pda-024-icb-RO-2024_01.zip
# pda-024-icb-RO-2024_01.zip: 100%|██████████| 1.80M/1.80M [00:00<00:00, 3.22MB/s]
# ZIP file saved at: ans_downloads/pda-024-icb-RO-2024_01.zip
# CSV extracted: ans_downloads/pda-024-icb-RO-2024_01.csv
# ['ans_downloads/pda-024-icb-AC-2024_01.csv', 'ans_downloads/pda-024-icb-RO-2024_01.csv']

# %%
df = pd.read_csv("combined.csv", delimiter=";")
